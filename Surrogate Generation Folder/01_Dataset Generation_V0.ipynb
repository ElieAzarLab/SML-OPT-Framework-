# %%
import pandas as pd 
import numpy as np
from eppy import modeleditor
from eppy.modeleditor import IDF
from pyDOE3 import lhs ## pyDOE3 is the new version of pyDOE
from scipy.stats import uniform ## to map the generated sample to a uniform distribution
import time 
import pyarrow as pa ## Not necessary. You can store the data in a csv file, but parquets are better 
import pyarrow.parquet as pq

# %% [markdown]
# ## IDD, IDF and EPW

# %%
idd="C:\EnergyPlusV23-2-0/Energy+.idd"
IDF.setiddname(idd)

# %%
idf_loc='C:\\Users\\Elin Markarian\\OneDrive - Carleton University\\Optimization_Seif\\FinalDOE\\DOE_V10.idf'
epw_loc='C:\\Users\\Elin Markarian\\OneDrive - Carleton University\\Optimization_Seif\\FinalDOE\\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw'

# %%
idf=IDF(idf_loc,epw_loc)

# %%
idf.idfobjects['OutputControl:Files']
# Out:
# [
# OutputControl:Files,
#     Yes,                      !- Output CSV
#     Yes,                      !- Output MTR
#     Yes,                      !- Output ESO
#     Yes,                      !- Output EIO
#     Yes,                      !- Output Tabular
#     Yes,                      !- Output SQLite
#     Yes,                      !- Output JSON
#     Yes,                      !- Output AUDIT
#     No,                       !- Output Zone Sizing
#     No,                       !- Output System Sizing
#     No,                       !- Output DXF
#     Yes,                      !- Output BND
#     Yes,                      !- Output RDD
#     Yes,                      !- Output MDD
#     Yes,                      !- Output MTD
#     Yes,                      !- Output END
#     Yes,                      !- Output SHD
#     Yes,                      !- Output DFS
#     Yes,                      !- Output GLHE
#     No,                       !- Output DelightIn
#     No,                       !- Output DelightELdmp
#     No,                       !- Output DelightDFdmp
#     Yes,                      !- Output EDD
#     Yes,                      !- Output DBG
#     Yes,                      !- Output PerfLog
#     Yes,                      !- Output SLN
#     Yes,                      !- Output SCI
#     Yes,                      !- Output WRL
#     No,                       !- Output Screen
#     No,                       !- Output ExtShd
#     No;                       !- Output Tarcog
# ]

# %%
idf.run()
# Out:
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_e01fd7.idf

# %% [markdown]
# ## Inputs and Ranges

# %%
U_wall_min= 0.126
U_wall_max= 0.264
U_roof_min= 0.09
U_roof_max= 0.152

# %%
## convert U_values to R_values
R_wall_max= 1/U_wall_min
R_wall_min= 1/U_wall_max
R_roof_min= 1/U_roof_max
R_roof_max= 1/U_roof_min

# %%
R_wall_max
# Out:
# 7.936507936507937

# %%
R_wall_min
# Out:
# 3.7878787878787876

# %%
print(R_roof_min)
print(R_roof_max)
# Out:
# 6.578947368421053
# 11.11111111111111

# %%
## Wall min and max R_insulation 
WR1= idf.idfobjects['Material'][-6].Thickness/idf.idfobjects['Material'][-6].Conductivity ##1IN Stucco
WR2= idf.idfobjects['Material'][-4].Thickness/idf.idfobjects['Material'][-4].Conductivity ##8IN CONCRETE HW RefBldg
WR_ins_min= R_wall_min-WR1-WR2
WR_ins_max= R_wall_max-WR1-WR2

# %%
WR_ins_min

# %%
WR_ins_max

# %%
### Roof min and max R_insulation 
RR1= idf.idfobjects['Material'][-1].Thickness/idf.idfobjects['Material'][-1].Conductivity ##BETB Asphalt Cover Board and Membrane
RR2= idf.idfobjects['Material'][-2].Thickness/idf.idfobjects['Material'][-2].Conductivity ##BETB Gypsum Board
RR3= idf.idfobjects['Material'][-3].Thickness/idf.idfobjects['Material'][-3].Conductivity ##BETB Steel Deck
R_ins_min= R_roof_min-RR1-RR2-RR3 ## Lower bound
R_ins_max= R_roof_max-RR1-RR2-RR3 ## Upper bound

# %%
R_ins_max

# %%
R_ins_min

# %%
idf.idfobjects['Construction'][0].Name="Elin"

# %%
idf.idfobjects['Construction'][0].Name
# Out:
# 'Elin'

# %%
idf.idfobjects['Construction'][-3]

# %%
idf.idfobjects['Material:NoMass']

# %%
idf.idfobjects['Material'][-6]

# %%
idf.idfobjects['Material'][-1]

# %%
idf.idfobjects['Material'][-1].Conductivity

# %%
idf.idfobjects['Material'][-1].Thickness

# %%
idf.idfobjects['Material'][-2]

# %%
idf.idfobjects['Material'][-3]

# %% [markdown]
# ## Inputs, Ranges and Distribution

# %%
ranges={
    'X1':{'min':WR_ins_min,'max':WR_ins_max}, ## Wall Insulation R_value
    'X2':{'min':R_ins_min,'max':R_ins_max}, ## Roof Insulation R_value
    'X3':{'min':1.1511,'max':1.903}, ## Window U_value
    'X4':{'min':0,'max':1}, ## SHGC
    'X5':{'min':2.407,'max':4.598}, ## COP-High Speed
    'X6':{'min':2.407,'max':4.598}, ## COP-Low Speed
    'X7':{'min':16,'max':22}, ## Occupied Heating SP
    'X8':{'min':16,'max':22}, ## UNOccupied Heating SP 
    'X9':{'min':22.01,'max':28}, ## Occupied Cooling SP
    'X10':{'min':22.01,'max':28} ## UNOccupied Cooling SP
}

# %%
len(ranges)

# %%
## Refer to: https://pydoe3.readthedocs.io/en/latest/randomized.html#latin-hypercube

# %%
n_samples= 500 ## Number of samples

# %%
lhs_samples= lhs(len(ranges), samples=n_samples, criterion='maximin', random_state=42)

# %%
lhs_samples

# %%
# Map LHS samples to the specified ranges
mapped_samples = np.zeros_like(lhs_samples)
for i, (variable, dist_info) in enumerate(ranges.items()):
    min_val = dist_info["min"]
    max_val = dist_info["max"]
    mapped_samples[:, i] = uniform.ppf(lhs_samples[:, i], loc=min_val, scale=(max_val - min_val))

# %%
samples=pd.DataFrame(mapped_samples)

# %%
samples=samples.rename({0:'X1',
                        1:'X2',
                        2:'X3',
                        3:'X4',
                        4:'X5',
                        5:'X6',
                        6:'X7',
                        7:'X8',
                        8:'X9',
                        9:'X10'}, axis=1)

# %%
df_samples=np.round(samples, 3)

# %%
print(df_samples['X9'].min())
print(df_samples['X9'].max())

# %%
df_samples.to_csv("C:\\Users\\Elin Markarian\\OneDrive - Carleton University\\Optimization_Seif\\Datasets\\Dataset_01\\InputsV01.csv", index=False)

# %%
df_samples
# Out:
#         X1     X2     X3     X4     X5     X6      X7      X8      X9     X10
# 0    5.948  9.867  1.652  0.357  4.446  3.435  19.168  19.793  23.400  22.025
# 1    7.482  7.247  1.604  0.918  4.087  4.165  17.382  18.326  27.333  26.114
# 2    7.629  7.381  1.671  0.700  3.949  3.632  18.311  17.273  22.550  24.061
# 3    5.715  8.797  1.693  0.934  3.572  3.658  18.209  19.397  22.365  22.252
# 4    6.584  7.771  1.677  0.919  2.684  2.433  19.514  19.038  22.634  24.032
# ..     ...    ...    ...    ...    ...    ...     ...     ...     ...     ...
# 495  3.986  8.955  1.639  0.301  3.858  3.229  18.474  19.720  22.663  23.256
# 496  7.572  9.386  1.600  0.056  4.349  4.125  20.456  21.423  26.873  22.475
# 497  4.182  9.518  1.252  0.932  3.718  2.777  17.911  17.079  25.455  23.669
# 498  7.640  8.285  1.324  0.948  4.225  2.589  18.303  21.072  27.202  23.023
# 499  4.017  7.253  1.478  0.453  2.800  3.813  18.574  17.738  22.202  26.474
#
# [500 rows x 10 columns]

# %% [markdown]
# ## Run Automation

# %%
df_samples=pd.read_csv("C:\\Users\\Elin Markarian\\OneDrive - Carleton University\\Optimization_Seif\\Datasets\\Dataset_01\\InputsV01.csv")

# %%
### Creating a parquet scheme using an existing EnergyPlus Result

EP_csv_loc= 'eplusout.csv'
EP_df = pd.read_csv(EP_csv_loc)

# creating the schema
schema = pa.Schema.from_pandas(EP_df)

## We need to add the "Run" column to the schema (We need the "Run" column so later we can match the inputs and outputs)
run_col = pa.field("Run", pa.int64())

new_schema = pa.schema([run_col] + [(field.name, field.type) for field in schema])

# Create a Table with the new schema
table = pa.Table.from_pandas(pd.DataFrame(columns=new_schema.names), schema=new_schema)


# Create the updated schema with the new field
#new_schema = pa.schema([run_col] + schema.fields)

# Assuming you have a Pandas DataFrame 'csv' with the "Run" column
#table = pa.Table.from_pandas(pd.DataFrame(columns=new_schema.names), schema=new_schema)

# Save the table to a Parquet file
pq.write_table(table, 'C:\\Users\\Elin Markarian\\OneDrive - Carleton University\\Optimization_Seif\\Datasets\\Dataset_01\\DatasetV01.parquet')

# %%
len(df_samples)
# Out:
# 500

# %%
idf.idfobjects['Material:NoMass']
# Out:
# [
# Material:NoMass,
#     CP02 CARPET PAD,          !- Name
#     VeryRough,                !- Roughness
#     0.2165,                   !- Thermal Resistance
#     0.9,                      !- Thermal Absorptance
#     0.7,                      !- Solar Absorptance
#     0.8;                      !- Visible Absorptance
# ,
# Material:NoMass,
#     MAT-AIR-WALL,             !- Name
#     Rough,                    !- Roughness
#     0.2079491,                !- Thermal Resistance
#     0.9,                      !- Thermal Absorptance
#     0.7;                      !- Solar Absorptance
# ,
# Material:NoMass,
#     NECB_RIns_Wall,           !- Name
#     Rough,                    !- Roughness
#     3.35,                     !- Thermal Resistance
#     0.9,                      !- Thermal Absorptance
#     0.7,                      !- Solar Absorptance
#     0.7;                      !- Visible Absorptance
# ,
# Material:NoMass,
#     NECB_RIns_Roof,           !- Name
#     Rough,                    !- Roughness
#     3.46,                     !- Thermal Resistance
#     0.9,                      !- Thermal Absorptance
#     0.7,                      !- Solar Absorptance
#     0.7;                      !- Visible Absorptance
# ,
# Material:NoMass,
#     NECB_CP02 CARPET PAD,     !- Name
#     VeryRough,                !- Roughness
#     1.25,                     !- Thermal Resistance
#     0.9,                      !- Thermal Absorptance
#     0.7,                      !- Solar Absorptance
#     0.8;                      !- Visible Absorptance
# ,
# Material:NoMass,
#     Typical Carpet Pad,       !- Name
#     Smooth,                   !- Roughness
#     1.2544,                   !- Thermal Resistance
#     0.9,                      !- Thermal Absorptance
#     0.7,                      !- Solar Absorptance
#     0.8;                      !- Visible Absorptance
# ,
# Material:NoMass,
#     Typical Insulation R-10.11,    !- Name
#     Smooth,                   !- Roughness
#     3.9758,                   !- Thermal Resistance
#     0.9,                      !- Thermal Absorptance
#     0.7,                      !- Solar Absorptance
#     0.7;                      !- Visible Absorptance
# ,
# Material:NoMass,
#     Roof Typical Carpet Pad,    !- Name
#     Smooth,                   !- Roughness
#     7.18,                     !- Thermal Resistance
#     0.9,                      !- Thermal Absorptance
#     0.7,                      !- Solar Absorptance
#     0.8;                      !- Visible Absorptance
# ,
# Material:NoMass,
#     BETB Mineral Wool,        !- Name
#     Rough,                    !- Roughness
#     7.137,                    !- Thermal Resistance
#     0.9,                      !- Thermal Absorptance
#     0.7,                      !- Solar Absorptance
#     0.7;                      !- Visible Absorptance
# ]

# %%
idf.idfobjects['Schedule:Compact'][-9]
# Out:
# Schedule:Compact,
#     NECB_HTGSETP_SCH,         !- Name
#     Temperature,              !- Schedule Type Limits Name
#     Through: 12/31,           !- Field 1
#     For: Weekdays,            !- Field 2
#     Until: 06:00,             !- Field 3
#     18,                       !- Field 4
#     Until: 07:00,             !- Field 5
#     20.0,                     !- Field 6
#     Until: 21:00,             !- Field 7
#     22,                       !- Field 8
#     Until: 24:00,             !- Field 9
#     18,                       !- Field 10
#     For SummerDesignDay,      !- Field 11
#     Until: 24:00,             !- Field 12
#     15.6,                     !- Field 13
#     For: WinterDesignDay,     !- Field 14
#     Until: 24:00,             !- Field 15
#     21.0,                     !- Field 16
#     For: Saturday Sunday AllOtherDays,    !- Field 17
#     Until: 24:00,             !- Field 18
#     18;                       !- Field 19

# %%
### Read the created Parquet table 
data_table = pq.read_table('C:\\Users\\Elin Markarian\\OneDrive - Carleton University\\Optimization_Seif\\Datasets\\Dataset_01\\DatasetV01.parquet') ## For hourly data
start_time=time.time()
annual_results = []

for i in range(len(df_samples)):
    X1=df_samples.loc[i,'X1'] ## Wall Insulation R_value
    X2=df_samples.loc[i,'X2'] ## Roof Insulation R_value
    X3=df_samples.loc[i,'X3'] ## Window U_value
    X4=df_samples.loc[i,'X4'] ## SHGC
    X5=df_samples.loc[i,'X5'] ## COP-High Speed
    X6=df_samples.loc[i,'X6'] ## COP-Low Speed
    X7=df_samples.loc[i,'X7'] ## Occupied Heating SP
    X8=df_samples.loc[i,'X8'] ## UNOccupied Heating SP
    X9=df_samples.loc[i,'X9'] ## Occupied Cooling SP
    X10=df_samples.loc[i,'X10'] ## UNOccupied Cooling SP

    idf.idfobjects['Material:NoMass'][-3].Thermal_Resistance=X1
    idf.idfobjects['Material:NoMass'][-1].Thermal_Resistance=X2
    idf.idfobjects['WindowMaterial:SimpleGlazingSystem'][0].UFactor=X3
    idf.idfobjects['WindowMaterial:SimpleGlazingSystem'][0].Solar_Heat_Gain_Coefficient=X4
    
    for coil in idf.idfobjects['Coil:Cooling:DX:TwoSpeed']:
        coil.High_Speed_Gross_Rated_Cooling_COP=X5
        coil.Low_Speed_Gross_Rated_Cooling_COP=X6
        
    idf.idfobjects['Schedule:Compact'][-9].Field_8=X7 ## Heating SP: 7-21
    idf.idfobjects['Schedule:Compact'][-9].Field_10=X8 ## Heating SP: 21-24
    idf.idfobjects['Schedule:Compact'][-9].Field_4=X8 ## Heating SP: 24-6
    idf.idfobjects['Schedule:Compact'][-10].Field_16=X9 ## Cooling SP 6-21
    idf.idfobjects['Schedule:Compact'][-10].Field_18= X10 ## Cooling SP 21-24
    idf.idfobjects['Schedule:Compact'][-10].Field_14= X10 ## Cooling SP 24-6
    
    idf.run()
    
    ## For hourly Electricity 
    file_path='eplusout.csv'
    csv=pd.read_csv('eplusout.csv')
    run_num = i  ## Run Number_used later to merge inputs and outputs
    csv['Run']=run_num
    
    record_batch = pa.RecordBatch.from_pandas(csv, schema=new_schema)

    # Append the new record batch to the existing table
    data_table = pa.concat_tables([data_table, pa.Table.from_pandas(csv, schema=new_schema)])

    # Save the updated table to the Parquet file
    pq.write_table(data_table,'C:\\Users\\Elin Markarian\\OneDrive - Carleton University\\Optimization_Seif\\Datasets\\Dataset_01\\DatasetV01.parquet')
    
    
    #Read annual data from eplusouttbl.csv
    file_loc = 'eplustbl.csv'
    # Specify the target rows and columns
    targets = {
        "Total_Site_Energy (GJ)": (14, 2),  # C15
        "Total_Natural_Gas (GJ)": (64, 3),  # D65
        "Total_Electricity (GJ)": (64, 2),  #C65
        "Unmet_ASHRAE_55 (hr)": (188, 2),  # C189
        "Peak_Electricity (W)": (323, 2)   # C324
            }
    results = {"Run": i}
#Open the file and process line-by-line
    with open(file_loc, 'r') as file:
        for row_index, line in enumerate(file):
            for key, (target_row, target_column) in targets.items():
                if row_index == target_row:
                    cells = line.split(',')
                    if len(cells) > target_column:
                        value = cells[target_column].strip()
                        results[key] = value
                        print(f"Extracted {key}: {value}")
        
        # Append the results of the current run to the annual results list
        annual_results.append(results)


# Convert results to a DataFrame
annual_results_df = pd.DataFrame(annual_results)

# Save annual results to a CSV file
annual_results_df.to_csv('C:\\Users\\Elin Markarian\\OneDrive - Carleton University\\Optimization_Seif\\Datasets\\Dataset_01\\Annual_V01.csv', index=False)

end_time=time.time()
run_time=end_time-start_time
print(run_time)
# Out:
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_4b5472.idf
#
# Extracted Total_Site_Energy (GJ): 1944.07
# Extracted Total_Natural_Gas (GJ): 251.32
# Extracted Total_Electricity (GJ): 1692.75
# Extracted Unmet_ASHRAE_55 (hr): 2452.83
# Extracted Peak_Electricity (W): 184351.94
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_3e1ad7.idf
#
# Extracted Total_Site_Energy (GJ): 1718.66
# Extracted Total_Natural_Gas (GJ): 132.73
# Extracted Total_Electricity (GJ): 1585.93
# Extracted Unmet_ASHRAE_55 (hr): 3196.83
# Extracted Peak_Electricity (W): 224329.50
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_68d5b1.idf
#
# Extracted Total_Site_Energy (GJ): 1786.40
# Extracted Total_Natural_Gas (GJ): 169.86
# Extracted Total_Electricity (GJ): 1616.54
# Extracted Unmet_ASHRAE_55 (hr): 2442.67
# Extracted Peak_Electricity (W): 241195.76
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_c1598e.idf
#
# Extracted Total_Site_Energy (GJ): 1948.75
# Extracted Total_Natural_Gas (GJ): 115.53
# Extracted Total_Electricity (GJ): 1833.22
# Extracted Unmet_ASHRAE_55 (hr): 2556.83
# Extracted Peak_Electricity (W): 203262.92
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_ca3c97.idf
#
# Extracted Total_Site_Energy (GJ): 2027.96
# Extracted Total_Natural_Gas (GJ): 107.33
# Extracted Total_Electricity (GJ): 1920.63
# Extracted Unmet_ASHRAE_55 (hr): 2264.67
# Extracted Peak_Electricity (W): 227034.83
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_95f455.idf
#
# Extracted Total_Site_Energy (GJ): 2000.44
# Extracted Total_Natural_Gas (GJ): 319.36
# Extracted Total_Electricity (GJ): 1681.09
# Extracted Unmet_ASHRAE_55 (hr): 2224.17
# Extracted Peak_Electricity (W): 197478.58
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_7ff119.idf
#
# Extracted Total_Site_Energy (GJ): 2121.68
# Extracted Total_Natural_Gas (GJ): 283.01
# Extracted Total_Electricity (GJ): 1838.68
# Extracted Unmet_ASHRAE_55 (hr): 2308.17
# Extracted Peak_Electricity (W): 222541.24
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_879ae9.idf
#
# Extracted Total_Site_Energy (GJ): 1690.15
# Extracted Total_Natural_Gas (GJ): 114.54
# Extracted Total_Electricity (GJ): 1575.61
# Extracted Unmet_ASHRAE_55 (hr): 2429.50
# Extracted Peak_Electricity (W): 229602.74
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_a10544.idf
#
# Extracted Total_Site_Energy (GJ): 1758.51
# Extracted Total_Natural_Gas (GJ): 202.63
# Extracted Total_Electricity (GJ): 1555.88
# Extracted Unmet_ASHRAE_55 (hr): 2943.00
# Extracted Peak_Electricity (W): 241763.87
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_1d36ea.idf
#
# Extracted Total_Site_Energy (GJ): 1847.64
# Extracted Total_Natural_Gas (GJ): 332.72
# Extracted Total_Electricity (GJ): 1514.92
# Extracted Unmet_ASHRAE_55 (hr): 2456.33
# Extracted Peak_Electricity (W): 192052.12
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_adb435.idf
#
# Extracted Total_Site_Energy (GJ): 1857.31
# Extracted Total_Natural_Gas (GJ): 189.68
# Extracted Total_Electricity (GJ): 1667.63
# Extracted Unmet_ASHRAE_55 (hr): 2781.50
# Extracted Peak_Electricity (W): 216431.91
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_bf28ef.idf
#
# Extracted Total_Site_Energy (GJ): 1881.73
# Extracted Total_Natural_Gas (GJ): 330.52
# Extracted Total_Electricity (GJ): 1551.21
# Extracted Unmet_ASHRAE_55 (hr): 2445.50
# Extracted Peak_Electricity (W): 171532.63
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_ee41d6.idf
#
# Extracted Total_Site_Energy (GJ): 1958.46
# Extracted Total_Natural_Gas (GJ): 88.67
# Extracted Total_Electricity (GJ): 1869.79
# Extracted Unmet_ASHRAE_55 (hr): 1578.17
# Extracted Peak_Electricity (W): 261727.75
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_e4b663.idf
#
# Extracted Total_Site_Energy (GJ): 1948.19
# Extracted Total_Natural_Gas (GJ): 340.77
# Extracted Total_Electricity (GJ): 1607.42
# Extracted Unmet_ASHRAE_55 (hr): 2438.50
# Extracted Peak_Electricity (W): 169281.15
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_ac55ba.idf
#
# Extracted Total_Site_Energy (GJ): 2055.66
# Extracted Total_Natural_Gas (GJ): 140.92
# Extracted Total_Electricity (GJ): 1914.74
# Extracted Unmet_ASHRAE_55 (hr): 2897.67
# Extracted Peak_Electricity (W): 271763.50
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_1c7f57.idf
#
# Extracted Total_Site_Energy (GJ): 1733.17
# Extracted Total_Natural_Gas (GJ): 155.52
# Extracted Total_Electricity (GJ): 1577.65
# Extracted Unmet_ASHRAE_55 (hr): 2885.33
# Extracted Peak_Electricity (W): 231758.37
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_746e95.idf
#
# Extracted Total_Site_Energy (GJ): 1990.93
# Extracted Total_Natural_Gas (GJ): 143.08
# Extracted Total_Electricity (GJ): 1847.85
# Extracted Unmet_ASHRAE_55 (hr): 1426.67
# Extracted Peak_Electricity (W): 254689.29
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_ea0cf8.idf
#
# Extracted Total_Site_Energy (GJ): 2171.90
# Extracted Total_Natural_Gas (GJ): 310.77
# Extracted Total_Electricity (GJ): 1861.12
# Extracted Unmet_ASHRAE_55 (hr): 1799.83
# Extracted Peak_Electricity (W): 214123.83
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_ece1e8.idf
#
# Extracted Total_Site_Energy (GJ): 2107.52
# Extracted Total_Natural_Gas (GJ): 135.24
# Extracted Total_Electricity (GJ): 1972.27
# Extracted Unmet_ASHRAE_55 (hr): 1173.83
# Extracted Peak_Electricity (W): 233042.04
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_74ab5c.idf
#
# Extracted Total_Site_Energy (GJ): 1959.07
# Extracted Total_Natural_Gas (GJ): 119.51
# Extracted Total_Electricity (GJ): 1839.55
# Extracted Unmet_ASHRAE_55 (hr): 1197.33
# Extracted Peak_Electricity (W): 263765.22
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_5e88a8.idf
#
# Extracted Total_Site_Energy (GJ): 1790.91
# Extracted Total_Natural_Gas (GJ): 156.46
# Extracted Total_Electricity (GJ): 1634.45
# Extracted Unmet_ASHRAE_55 (hr): 3131.00
# Extracted Peak_Electricity (W): 223604.13
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_b4fa56.idf
#
# Extracted Total_Site_Energy (GJ): 2035.71
# Extracted Total_Natural_Gas (GJ): 105.74
# Extracted Total_Electricity (GJ): 1929.97
# Extracted Unmet_ASHRAE_55 (hr): 2765.00
# Extracted Peak_Electricity (W): 257131.37
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_e789a3.idf
#
# Extracted Total_Site_Energy (GJ): 1730.83
# Extracted Total_Natural_Gas (GJ): 262.26
# Extracted Total_Electricity (GJ): 1468.57
# Extracted Unmet_ASHRAE_55 (hr): 2654.50
# Extracted Peak_Electricity (W): 225738.04
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_b46b9a.idf
#
# Extracted Total_Site_Energy (GJ): 2069.95
# Extracted Total_Natural_Gas (GJ): 279.72
# Extracted Total_Electricity (GJ): 1790.22
# Extracted Unmet_ASHRAE_55 (hr): 2417.00
# Extracted Peak_Electricity (W): 223785.67
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_73fb5f.idf
#
# Extracted Total_Site_Energy (GJ): 1969.68
# Extracted Total_Natural_Gas (GJ): 312.14
# Extracted Total_Electricity (GJ): 1657.54
# Extracted Unmet_ASHRAE_55 (hr): 2252.83
# Extracted Peak_Electricity (W): 197540.33
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_57bb65.idf
#
# Extracted Total_Site_Energy (GJ): 1768.34
# Extracted Total_Natural_Gas (GJ): 125.99
# Extracted Total_Electricity (GJ): 1642.35
# Extracted Unmet_ASHRAE_55 (hr): 2995.33
# Extracted Peak_Electricity (W): 251914.66
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_8f8ebf.idf
#
# Extracted Total_Site_Energy (GJ): 1738.48
# Extracted Total_Natural_Gas (GJ): 140.48
# Extracted Total_Electricity (GJ): 1598.01
# Extracted Unmet_ASHRAE_55 (hr): 2697.83
# Extracted Peak_Electricity (W): 232522.72
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_4b11fe.idf
#
# Extracted Total_Site_Energy (GJ): 1924.28
# Extracted Total_Natural_Gas (GJ): 81.20
# Extracted Total_Electricity (GJ): 1843.08
# Extracted Unmet_ASHRAE_55 (hr): 1155.17
# Extracted Peak_Electricity (W): 251913.38
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_619aab.idf
#
# Extracted Total_Site_Energy (GJ): 1836.64
# Extracted Total_Natural_Gas (GJ): 266.56
# Extracted Total_Electricity (GJ): 1570.08
# Extracted Unmet_ASHRAE_55 (hr): 1696.83
# Extracted Peak_Electricity (W): 230559.01
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_a6dd6e.idf
#
# Extracted Total_Site_Energy (GJ): 1973.06
# Extracted Total_Natural_Gas (GJ): 161.53
# Extracted Total_Electricity (GJ): 1811.53
# Extracted Unmet_ASHRAE_55 (hr): 2395.17
# Extracted Peak_Electricity (W): 213750.02
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_4c4eeb.idf
#
# Extracted Total_Site_Energy (GJ): 1939.00
# Extracted Total_Natural_Gas (GJ): 338.65
# Extracted Total_Electricity (GJ): 1600.35
# Extracted Unmet_ASHRAE_55 (hr): 2346.17
# Extracted Peak_Electricity (W): 181097.22
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_bcece5.idf
#
# Extracted Total_Site_Energy (GJ): 2088.95
# Extracted Total_Natural_Gas (GJ): 275.13
# Extracted Total_Electricity (GJ): 1813.81
# Extracted Unmet_ASHRAE_55 (hr): 1253.83
# Extracted Peak_Electricity (W): 235123.60
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_b8d0c1.idf
#
# Extracted Total_Site_Energy (GJ): 1897.38
# Extracted Total_Natural_Gas (GJ): 89.24
# Extracted Total_Electricity (GJ): 1808.14
# Extracted Unmet_ASHRAE_55 (hr): 2171.83
# Extracted Peak_Electricity (W): 256001.42
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_27b435.idf
#
# Extracted Total_Site_Energy (GJ): 1864.33
# Extracted Total_Natural_Gas (GJ): 241.48
# Extracted Total_Electricity (GJ): 1622.85
# Extracted Unmet_ASHRAE_55 (hr): 2794.50
# Extracted Peak_Electricity (W): 185862.23
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_5a0017.idf
#
# Extracted Total_Site_Energy (GJ): 1887.06
# Extracted Total_Natural_Gas (GJ): 126.91
# Extracted Total_Electricity (GJ): 1760.15
# Extracted Unmet_ASHRAE_55 (hr): 2549.33
# Extracted Peak_Electricity (W): 196972.05
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_4b1925.idf
#
# Extracted Total_Site_Energy (GJ): 1937.67
# Extracted Total_Natural_Gas (GJ): 317.98
# Extracted Total_Electricity (GJ): 1619.69
# Extracted Unmet_ASHRAE_55 (hr): 2375.50
# Extracted Peak_Electricity (W): 195653.85
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_d49a69.idf
#
# Extracted Total_Site_Energy (GJ): 1976.84
# Extracted Total_Natural_Gas (GJ): 277.87
# Extracted Total_Electricity (GJ): 1698.97
# Extracted Unmet_ASHRAE_55 (hr): 2362.33
# Extracted Peak_Electricity (W): 211651.48
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_7b2966.idf
#
# Extracted Total_Site_Energy (GJ): 1849.77
# Extracted Total_Natural_Gas (GJ): 230.00
# Extracted Total_Electricity (GJ): 1619.77
# Extracted Unmet_ASHRAE_55 (hr): 2439.17
# Extracted Peak_Electricity (W): 197698.39
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_ddfd28.idf
#
# Extracted Total_Site_Energy (GJ): 2008.92
# Extracted Total_Natural_Gas (GJ): 218.38
# Extracted Total_Electricity (GJ): 1790.54
# Extracted Unmet_ASHRAE_55 (hr): 1251.00
# Extracted Peak_Electricity (W): 254822.24
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_4ebb61.idf
#
# Extracted Total_Site_Energy (GJ): 1840.63
# Extracted Total_Natural_Gas (GJ): 371.83
# Extracted Total_Electricity (GJ): 1468.80
# Extracted Unmet_ASHRAE_55 (hr): 2452.33
# Extracted Peak_Electricity (W): 178190.65
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_19c03f.idf
#
# Extracted Total_Site_Energy (GJ): 2042.66
# Extracted Total_Natural_Gas (GJ): 388.24
# Extracted Total_Electricity (GJ): 1654.42
# Extracted Unmet_ASHRAE_55 (hr): 2359.83
# Extracted Peak_Electricity (W): 220379.88
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_35c090.idf
#
# Extracted Total_Site_Energy (GJ): 2062.27
# Extracted Total_Natural_Gas (GJ): 277.27
# Extracted Total_Electricity (GJ): 1785.01
# Extracted Unmet_ASHRAE_55 (hr): 2307.33
# Extracted Peak_Electricity (W): 225193.75
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_f85b22.idf
#
# Extracted Total_Site_Energy (GJ): 2053.65
# Extracted Total_Natural_Gas (GJ): 324.76
# Extracted Total_Electricity (GJ): 1728.89
# Extracted Unmet_ASHRAE_55 (hr): 1952.50
# Extracted Peak_Electricity (W): 205054.34
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_2ed62a.idf
#
# Extracted Total_Site_Energy (GJ): 1877.48
# Extracted Total_Natural_Gas (GJ): 157.85
# Extracted Total_Electricity (GJ): 1719.63
# Extracted Unmet_ASHRAE_55 (hr): 3053.00
# Extracted Peak_Electricity (W): 200901.07
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_347bfd.idf
#
# Extracted Total_Site_Energy (GJ): 1847.98
# Extracted Total_Natural_Gas (GJ): 161.33
# Extracted Total_Electricity (GJ): 1686.65
# Extracted Unmet_ASHRAE_55 (hr): 2792.83
# Extracted Peak_Electricity (W): 186971.81
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_f8b774.idf
#
# Extracted Total_Site_Energy (GJ): 1722.94
# Extracted Total_Natural_Gas (GJ): 162.82
# Extracted Total_Electricity (GJ): 1560.12
# Extracted Unmet_ASHRAE_55 (hr): 3078.00
# Extracted Peak_Electricity (W): 232539.05
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_b85fc2.idf
#
# Extracted Total_Site_Energy (GJ): 1914.12
# Extracted Total_Natural_Gas (GJ): 185.84
# Extracted Total_Electricity (GJ): 1728.28
# Extracted Unmet_ASHRAE_55 (hr): 2576.67
# Extracted Peak_Electricity (W): 203201.11
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_5b5ccb.idf
#
# Extracted Total_Site_Energy (GJ): 1994.52
# Extracted Total_Natural_Gas (GJ): 379.43
# Extracted Total_Electricity (GJ): 1615.09
# Extracted Unmet_ASHRAE_55 (hr): 2299.17
# Extracted Peak_Electricity (W): 204372.53
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_c1641e.idf
#
# Extracted Total_Site_Energy (GJ): 1937.86
# Extracted Total_Natural_Gas (GJ): 129.80
# Extracted Total_Electricity (GJ): 1808.06
# Extracted Unmet_ASHRAE_55 (hr): 2645.67
# Extracted Peak_Electricity (W): 234222.17
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_b85fb8.idf
#
# Extracted Total_Site_Energy (GJ): 1871.22
# Extracted Total_Natural_Gas (GJ): 276.95
# Extracted Total_Electricity (GJ): 1594.26
# Extracted Unmet_ASHRAE_55 (hr): 2512.00
# Extracted Peak_Electricity (W): 231163.45
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_0261fb.idf
#
# Extracted Total_Site_Energy (GJ): 1814.15
# Extracted Total_Natural_Gas (GJ): 160.08
# Extracted Total_Electricity (GJ): 1654.08
# Extracted Unmet_ASHRAE_55 (hr): 3192.00
# Extracted Peak_Electricity (W): 244606.37
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_fc77fe.idf
#
# Extracted Total_Site_Energy (GJ): 1999.80
# Extracted Total_Natural_Gas (GJ): 379.01
# Extracted Total_Electricity (GJ): 1620.80
# Extracted Unmet_ASHRAE_55 (hr): 2451.50
# Extracted Peak_Electricity (W): 173005.29
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_ebfb29.idf
#
# Extracted Total_Site_Energy (GJ): 1840.58
# Extracted Total_Natural_Gas (GJ): 292.51
# Extracted Total_Electricity (GJ): 1548.08
# Extracted Unmet_ASHRAE_55 (hr): 2367.33
# Extracted Peak_Electricity (W): 183383.38
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_5aa07c.idf
#
# Extracted Total_Site_Energy (GJ): 1989.88
# Extracted Total_Natural_Gas (GJ): 117.71
# Extracted Total_Electricity (GJ): 1872.17
# Extracted Unmet_ASHRAE_55 (hr): 2583.67
# Extracted Peak_Electricity (W): 265796.67
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_133fb0.idf
#
# Extracted Total_Site_Energy (GJ): 2221.14
# Extracted Total_Natural_Gas (GJ): 275.13
# Extracted Total_Electricity (GJ): 1946.00
# Extracted Unmet_ASHRAE_55 (hr): 1452.17
# Extracted Peak_Electricity (W): 221003.45
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_840c36.idf
#
# Extracted Total_Site_Energy (GJ): 1968.46
# Extracted Total_Natural_Gas (GJ): 193.43
# Extracted Total_Electricity (GJ): 1775.04
# Extracted Unmet_ASHRAE_55 (hr): 2364.00
# Extracted Peak_Electricity (W): 242353.63
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_786fa4.idf
#
# Extracted Total_Site_Energy (GJ): 1971.01
# Extracted Total_Natural_Gas (GJ): 97.61
# Extracted Total_Electricity (GJ): 1873.39
# Extracted Unmet_ASHRAE_55 (hr): 2496.83
# Extracted Peak_Electricity (W): 270311.97
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_0277d3.idf
#
# Extracted Total_Site_Energy (GJ): 1913.25
# Extracted Total_Natural_Gas (GJ): 169.21
# Extracted Total_Electricity (GJ): 1744.04
# Extracted Unmet_ASHRAE_55 (hr): 1319.33
# Extracted Peak_Electricity (W): 263465.09
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_ca11af.idf
#
# Extracted Total_Site_Energy (GJ): 1914.32
# Extracted Total_Natural_Gas (GJ): 327.31
# Extracted Total_Electricity (GJ): 1587.01
# Extracted Unmet_ASHRAE_55 (hr): 2448.17
# Extracted Peak_Electricity (W): 182188.89
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_5df821.idf
#
# Extracted Total_Site_Energy (GJ): 2185.28
# Extracted Total_Natural_Gas (GJ): 124.56
# Extracted Total_Electricity (GJ): 2060.73
# Extracted Unmet_ASHRAE_55 (hr): 2326.83
# Extracted Peak_Electricity (W): 270723.94
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_16bd5b.idf
#
# Extracted Total_Site_Energy (GJ): 1994.37
# Extracted Total_Natural_Gas (GJ): 131.85
# Extracted Total_Electricity (GJ): 1862.53
# Extracted Unmet_ASHRAE_55 (hr): 3111.00
# Extracted Peak_Electricity (W): 240430.67
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_c04c06.idf
#
# Extracted Total_Site_Energy (GJ): 2113.26
# Extracted Total_Natural_Gas (GJ): 144.09
# Extracted Total_Electricity (GJ): 1969.17
# Extracted Unmet_ASHRAE_55 (hr): 1950.83
# Extracted Peak_Electricity (W): 236743.52
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_494731.idf
#
# Extracted Total_Site_Energy (GJ): 1673.14
# Extracted Total_Natural_Gas (GJ): 145.42
# Extracted Total_Electricity (GJ): 1527.73
# Extracted Unmet_ASHRAE_55 (hr): 3015.67
# Extracted Peak_Electricity (W): 249839.81
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_e06b99.idf
#
# Extracted Total_Site_Energy (GJ): 2056.86
# Extracted Total_Natural_Gas (GJ): 316.97
# Extracted Total_Electricity (GJ): 1739.90
# Extracted Unmet_ASHRAE_55 (hr): 1799.50
# Extracted Peak_Electricity (W): 194559.53
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_4e7bea.idf
#
# Extracted Total_Site_Energy (GJ): 1958.47
# Extracted Total_Natural_Gas (GJ): 208.96
# Extracted Total_Electricity (GJ): 1749.51
# Extracted Unmet_ASHRAE_55 (hr): 1484.17
# Extracted Peak_Electricity (W): 223926.21
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_312c39.idf
#
# Extracted Total_Site_Energy (GJ): 1824.01
# Extracted Total_Natural_Gas (GJ): 177.84
# Extracted Total_Electricity (GJ): 1646.17
# Extracted Unmet_ASHRAE_55 (hr): 2451.83
# Extracted Peak_Electricity (W): 254884.66
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_63b131.idf
#
# Extracted Total_Site_Energy (GJ): 1779.08
# Extracted Total_Natural_Gas (GJ): 224.30
# Extracted Total_Electricity (GJ): 1554.78
# Extracted Unmet_ASHRAE_55 (hr): 2530.17
# Extracted Peak_Electricity (W): 227637.64
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_932c0a.idf
#
# Extracted Total_Site_Energy (GJ): 2096.23
# Extracted Total_Natural_Gas (GJ): 127.46
# Extracted Total_Electricity (GJ): 1968.77
# Extracted Unmet_ASHRAE_55 (hr): 1967.83
# Extracted Peak_Electricity (W): 253728.61
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_86a1a3.idf
#
# Extracted Total_Site_Energy (GJ): 1941.09
# Extracted Total_Natural_Gas (GJ): 144.28
# Extracted Total_Electricity (GJ): 1796.81
# Extracted Unmet_ASHRAE_55 (hr): 2371.83
# Extracted Peak_Electricity (W): 226837.92
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_607c47.idf
#
# Extracted Total_Site_Energy (GJ): 1838.91
# Extracted Total_Natural_Gas (GJ): 164.70
# Extracted Total_Electricity (GJ): 1674.21
# Extracted Unmet_ASHRAE_55 (hr): 2235.17
# Extracted Peak_Electricity (W): 209328.06
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_94bbc5.idf
#
# Extracted Total_Site_Energy (GJ): 1941.20
# Extracted Total_Natural_Gas (GJ): 140.77
# Extracted Total_Electricity (GJ): 1800.43
# Extracted Unmet_ASHRAE_55 (hr): 2414.67
# Extracted Peak_Electricity (W): 238067.39
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_91e577.idf
#
# Extracted Total_Site_Energy (GJ): 1927.49
# Extracted Total_Natural_Gas (GJ): 169.33
# Extracted Total_Electricity (GJ): 1758.17
# Extracted Unmet_ASHRAE_55 (hr): 1852.83
# Extracted Peak_Electricity (W): 239977.55
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_fcff4b.idf
#
# Extracted Total_Site_Energy (GJ): 2051.44
# Extracted Total_Natural_Gas (GJ): 315.14
# Extracted Total_Electricity (GJ): 1736.31
# Extracted Unmet_ASHRAE_55 (hr): 2301.83
# Extracted Peak_Electricity (W): 191494.14
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_136995.idf
#
# Extracted Total_Site_Energy (GJ): 2176.43
# Extracted Total_Natural_Gas (GJ): 196.20
# Extracted Total_Electricity (GJ): 1980.24
# Extracted Unmet_ASHRAE_55 (hr): 2086.83
# Extracted Peak_Electricity (W): 252487.11
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_65d680.idf
#
# Extracted Total_Site_Energy (GJ): 1823.37
# Extracted Total_Natural_Gas (GJ): 279.68
# Extracted Total_Electricity (GJ): 1543.69
# Extracted Unmet_ASHRAE_55 (hr): 2457.83
# Extracted Peak_Electricity (W): 220897.78
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_42b8bb.idf
#
# Extracted Total_Site_Energy (GJ): 1893.80
# Extracted Total_Natural_Gas (GJ): 92.90
# Extracted Total_Electricity (GJ): 1800.90
# Extracted Unmet_ASHRAE_55 (hr): 905.83
# Extracted Peak_Electricity (W): 253090.71
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_002a05.idf
#
# Extracted Total_Site_Energy (GJ): 1964.47
# Extracted Total_Natural_Gas (GJ): 272.73
# Extracted Total_Electricity (GJ): 1691.74
# Extracted Unmet_ASHRAE_55 (hr): 2341.00
# Extracted Peak_Electricity (W): 205407.65
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_d4dcfd.idf
#
# Extracted Total_Site_Energy (GJ): 1895.46
# Extracted Total_Natural_Gas (GJ): 229.97
# ...
#
# Extracted Total_Site_Energy (GJ): 1800.08
# Extracted Total_Natural_Gas (GJ): 352.54
# Extracted Total_Electricity (GJ): 1447.54
# Extracted Unmet_ASHRAE_55 (hr): 2454.00
# Extracted Peak_Electricity (W): 200215.22
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_9aba43.idf
#
# Extracted Total_Site_Energy (GJ): 1739.82
# Extracted Total_Natural_Gas (GJ): 149.62
# Extracted Total_Electricity (GJ): 1590.20
# Extracted Unmet_ASHRAE_55 (hr): 3156.50
# Extracted Peak_Electricity (W): 254007.46
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_65c7a3.idf
#
# Extracted Total_Site_Energy (GJ): 1792.80
# Extracted Total_Natural_Gas (GJ): 166.22
# Extracted Total_Electricity (GJ): 1626.58
# Extracted Unmet_ASHRAE_55 (hr): 3002.17
# Extracted Peak_Electricity (W): 197400.22
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_9cf1f7.idf
#
# Extracted Total_Site_Energy (GJ): 1936.34
# Extracted Total_Natural_Gas (GJ): 242.44
# Extracted Total_Electricity (GJ): 1693.90
# Extracted Unmet_ASHRAE_55 (hr): 2244.33
# Extracted Peak_Electricity (W): 223154.29
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_6f3676.idf
#
# Extracted Total_Site_Energy (GJ): 1728.78
# Extracted Total_Natural_Gas (GJ): 211.79
# Extracted Total_Electricity (GJ): 1516.98
# Extracted Unmet_ASHRAE_55 (hr): 2469.67
# Extracted Peak_Electricity (W): 189582.79
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_21a66e.idf
#
# Extracted Total_Site_Energy (GJ): 1774.47
# Extracted Total_Natural_Gas (GJ): 275.43
# Extracted Total_Electricity (GJ): 1499.04
# Extracted Unmet_ASHRAE_55 (hr): 2614.17
# Extracted Peak_Electricity (W): 176099.82
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_b2035d.idf
#
# Extracted Total_Site_Energy (GJ): 1888.54
# Extracted Total_Natural_Gas (GJ): 163.50
# Extracted Total_Electricity (GJ): 1725.04
# Extracted Unmet_ASHRAE_55 (hr): 1502.50
# Extracted Peak_Electricity (W): 240851.70
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_6344e3.idf
#
# Extracted Total_Site_Energy (GJ): 1943.03
# Extracted Total_Natural_Gas (GJ): 301.19
# Extracted Total_Electricity (GJ): 1641.84
# Extracted Unmet_ASHRAE_55 (hr): 2049.33
# Extracted Peak_Electricity (W): 225239.80
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_1e184f.idf
#
# Extracted Total_Site_Energy (GJ): 1763.34
# Extracted Total_Natural_Gas (GJ): 124.45
# Extracted Total_Electricity (GJ): 1638.89
# Extracted Unmet_ASHRAE_55 (hr): 2802.00
# Extracted Peak_Electricity (W): 173256.21
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_4fd302.idf
#
# Extracted Total_Site_Energy (GJ): 1924.08
# Extracted Total_Natural_Gas (GJ): 252.30
# Extracted Total_Electricity (GJ): 1671.79
# Extracted Unmet_ASHRAE_55 (hr): 2471.17
# Extracted Peak_Electricity (W): 219840.84
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_684a37.idf
#
# Extracted Total_Site_Energy (GJ): 1871.06
# Extracted Total_Natural_Gas (GJ): 148.22
# Extracted Total_Electricity (GJ): 1722.83
# Extracted Unmet_ASHRAE_55 (hr): 2584.83
# Extracted Peak_Electricity (W): 264496.17
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_1c7395.idf
#
# Extracted Total_Site_Energy (GJ): 2014.02
# Extracted Total_Natural_Gas (GJ): 342.24
# Extracted Total_Electricity (GJ): 1671.79
# Extracted Unmet_ASHRAE_55 (hr): 2372.33
# Extracted Peak_Electricity (W): 193731.70
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_456a18.idf
#
# Extracted Total_Site_Energy (GJ): 1804.23
# Extracted Total_Natural_Gas (GJ): 206.39
# Extracted Total_Electricity (GJ): 1597.84
# Extracted Unmet_ASHRAE_55 (hr): 2918.50
# Extracted Peak_Electricity (W): 215986.71
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_2cb906.idf
#
# Extracted Total_Site_Energy (GJ): 1912.97
# Extracted Total_Natural_Gas (GJ): 146.23
# Extracted Total_Electricity (GJ): 1766.74
# Extracted Unmet_ASHRAE_55 (hr): 2385.50
# Extracted Peak_Electricity (W): 214312.06
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_d3a5dc.idf
#
# Extracted Total_Site_Energy (GJ): 1681.88
# Extracted Total_Natural_Gas (GJ): 214.51
# Extracted Total_Electricity (GJ): 1467.37
# Extracted Unmet_ASHRAE_55 (hr): 2398.67
# Extracted Peak_Electricity (W): 233556.16
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_a18311.idf
#
# Extracted Total_Site_Energy (GJ): 2108.47
# Extracted Total_Natural_Gas (GJ): 261.48
# Extracted Total_Electricity (GJ): 1846.99
# Extracted Unmet_ASHRAE_55 (hr): 2544.83
# Extracted Peak_Electricity (W): 233239.82
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_2fdd87.idf
#
# Extracted Total_Site_Energy (GJ): 2034.76
# Extracted Total_Natural_Gas (GJ): 189.62
# Extracted Total_Electricity (GJ): 1845.14
# Extracted Unmet_ASHRAE_55 (hr): 2872.67
# Extracted Peak_Electricity (W): 260885.82
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_be37c1.idf
#
# Extracted Total_Site_Energy (GJ): 1789.54
# Extracted Total_Natural_Gas (GJ): 101.39
# Extracted Total_Electricity (GJ): 1688.15
# Extracted Unmet_ASHRAE_55 (hr): 1756.83
# Extracted Peak_Electricity (W): 231916.96
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_c153c8.idf
#
# Extracted Total_Site_Energy (GJ): 1989.01
# Extracted Total_Natural_Gas (GJ): 317.09
# Extracted Total_Electricity (GJ): 1671.92
# Extracted Unmet_ASHRAE_55 (hr): 2266.17
# Extracted Peak_Electricity (W): 213929.55
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_3e8653.idf
#
# Extracted Total_Site_Energy (GJ): 1993.75
# Extracted Total_Natural_Gas (GJ): 191.41
# Extracted Total_Electricity (GJ): 1802.34
# Extracted Unmet_ASHRAE_55 (hr): 2581.50
# Extracted Peak_Electricity (W): 250456.43
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_cc49ba.idf
#
# Extracted Total_Site_Energy (GJ): 1873.88
# Extracted Total_Natural_Gas (GJ): 223.50
# Extracted Total_Electricity (GJ): 1650.38
# Extracted Unmet_ASHRAE_55 (hr): 2940.67
# Extracted Peak_Electricity (W): 245522.79
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_6a83f8.idf
#
# Extracted Total_Site_Energy (GJ): 1971.11
# Extracted Total_Natural_Gas (GJ): 277.39
# Extracted Total_Electricity (GJ): 1693.72
# Extracted Unmet_ASHRAE_55 (hr): 2453.33
# Extracted Peak_Electricity (W): 184141.25
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_640423.idf
#
# Extracted Total_Site_Energy (GJ): 2071.55
# Extracted Total_Natural_Gas (GJ): 360.18
# Extracted Total_Electricity (GJ): 1711.36
# Extracted Unmet_ASHRAE_55 (hr): 2209.50
# Extracted Peak_Electricity (W): 193512.03
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_3ea9ee.idf
#
# Extracted Total_Site_Energy (GJ): 1747.03
# Extracted Total_Natural_Gas (GJ): 124.15
# Extracted Total_Electricity (GJ): 1622.88
# Extracted Unmet_ASHRAE_55 (hr): 3142.33
# Extracted Peak_Electricity (W): 239067.68
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_35de95.idf
#
# Extracted Total_Site_Energy (GJ): 2032.54
# Extracted Total_Natural_Gas (GJ): 103.15
# Extracted Total_Electricity (GJ): 1929.40
# Extracted Unmet_ASHRAE_55 (hr): 3066.67
# Extracted Peak_Electricity (W): 243260.81
#
# C:\EnergyPlusV23-2-0\energyplus.exe --weather C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\CAN_ON_OTTAWA-INTL-A_6106001_CWEC.epw --output-directory C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\Notebooks --idd C:\EnergyPlusV23-2-0\Energy+.idd C:\Users\Elin Markarian\OneDrive - Carleton University\Optimization_Seif\FinalDOE\DOE_V10_e7f3ab.idf
#
# Extracted Total_Site_Energy (GJ): 1840.78
# Extracted Total_Natural_Gas (GJ): 234.11
# Extracted Total_Electricity (GJ): 1606.68
# Extracted Unmet_ASHRAE_55 (hr): 2450.00
# Extracted Peak_Electricity (W): 217627.98
# 20385.51896905899
